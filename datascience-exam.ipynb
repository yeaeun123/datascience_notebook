# %% [markdown]
# ## 연습문제 1
#
# - pandas를 임포트 한 후
# - data 디렉터리로부터 wstudents.csv를 불러와 DataFrame에 담아 주십시오

# %%
# 여기에 코드를 작성해 주십시오
import pandas as pd
wstudents_df=pd.read_csv("./data/wstudents.csv", sep=",")
wstudents_df
# Out:
#     height  weights
# 0      151       48
# 1      154       44
# 2      160       48
# 3      160       52
# 4      163       58
# ..     ...      ...
# 75     156       47
# 76     159       47
# 77     156       52
# 78     156       47
# 79     161       50
#
# [80 rows x 2 columns]

# %% [markdown]
# ## 연습문제 2
# - 데이터프레임에는 어떤 컬럼들이 있습니까?
# ```
# Index(['height', 'weights'], dtype='object')
# ```

# %%
# 여기에 코드를 작성해 주십시오
wstudents_df.columns
# Out:
# Index(['height', 'weights'], dtype='object')

# %% [markdown]
# ## 연습문제 3
#
# - 생성한 데이터프레임의 크기를 측정해 주십시오.
# - 출력 예시는 다음과 같습니다.
#
# ```
# (80, 2)
# ```

# %%
# 여기에 코드를 작성해 주십시오
wstudents_df.shape  # (행크기, 열크기)
print(f"{wstudents_df.shape[0]}행 x {wstudents_df.shape[1]}열")
# Out:
# 80행 x 2열

# %% [markdown]
# ## 연습문제 4
# - 데이터프레임의 앞쪽 데이터를 출력해 주십시오
# - 출력 개수는 Pandas 기본 설정값으로 합니다.

# %%
# 여기에 코드를 작성해 주십시오
wstudents_df.head(n=5)
# Out:
#    height  weights
# 0     151       48
# 1     154       44
# 2     160       48
# 3     160       52
# 4     163       58

# %% [markdown]
# ## 연습문제 5
# - 데이터프레임의 뒤쪽 데이터를 일부 출력해 주십시오
# - 출력 개수는 Pandas 기본 설정값으로 합니다.

# %%
# 여기에 코드를 작성해 주십시오
wstudents_df.tail()
# Out:
#     height  weights
# 75     156       47
# 76     159       47
# 77     156       52
# 78     156       47
# 79     161       50

# %% [markdown]
# ## 연습문제 6
# - 데이터프레임의 전반적 정보를 확인해 주십시오
# - 출력 예시는 아래와 같습니다
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 2 columns):
# height     80 non-null int64
# weights    80 non-null int64
# dtypes: int64(2)
# memory usage: 1.3 KB
# ```

# %%
# 여기에 코드를 작성해 주십시오
wstudents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   height   80 non-null     int64
#  1   weights  80 non-null     int64
# dtypes: int64(2)
# memory usage: 1.4 KB

# %% [markdown]
# ## 연습문제 7
# - 데이터프레임의 요약통계량을 출력해 주십시오
# - 출력 예시는 다음과 같습니다.
# ```
#            height    weights
# count   80.000000  80.000000
# mean   157.425000  50.700000
# std      5.437272   6.267053
# min    143.000000  38.000000
# 25%    154.000000  47.000000
# 50%    157.000000  50.000000
# 75%    161.000000  54.000000
# max    169.000000  69.000000
# ```

# %%
# 여기에 코드를 작성해 주십시오
wstudents_df.describe()
# Out:
#            height    weights
# count   80.000000  80.000000
# mean   157.425000  50.700000
# std      5.437272   6.267053
# min    143.000000  38.000000
# 25%    154.000000  47.000000
# 50%    157.000000  50.000000
# 75%    161.000000  54.000000
# max    169.000000  69.000000

# %% [markdown]
# ## 연습문제 8
# - 데이터프레임으로부터 평균 신장과 평균 체중을 구해 출력해 주십시오
# - 출력 예시는 다음과 같습니다.
#
# ```
# 평균신장: 157.425
# 평균체중: 50.7
# ```

# %%
# 여기에 코드를 작성해 주십시오
print(wstudents_df.mean())
# Out:
# height     157.425
# weights     50.700
# dtype: float64

# %% [markdown]
# # 연습문제 9
# - 데이터프레임으로부터 체중이 45kg 이하인 학생의 데이터를 추출해 주십시오
# - 출력 예시는 다음과 같습니다.
# ```
#     height  weights
# 1      154       44
# 8      154       45
# 12     156       43
# ```

# %%
# 여기에 코드를 작성해 주십시오
filtered_df = wstudents_df[wstudents_df['weights'] < 45]
filtered_df
# Out:
#     height  weights
# 1      154       44
# 12     156       43
# 18     150       38
# 25     153       40
# 26     155       40
# 50     146       43
# 53     143       42
# 64     146       44
# 70     151       43

# %% [markdown]
# ## 연습문제 10
# - 데이터프레임으로부터 신장이 평균신장보다 큰 학생의 데이터를 추출해 주십시오
# - 출력 예시는 다음과 같습니다.
# ```
#     height  weights
# 2      160       48
# 3      160       52
# 4      163       58
# ...
# ```

# %%
# 여기에 코드를 작성해 주십시오
filtered_df = wstudents_df[wstudents_df['height'] > wstudents_df.mean()['height']]
filtered_df
# Out:
#     height  weights
# 2      160       48
# 3      160       52
# 4      163       58
# 6      158       62
# 9      160       55
# 11     162       47
# 13     162       53
# 15     162       64
# 16     162       47
# 17     169       61
# 22     161       46
# 23     160       47
# 24     160       45
# 27     163       55
# 28     160       62
# 29     159       50
# 30     164       50
# 31     158       46
# 35     161       57
# 36     168       60
# 37     162       55
# 40     158       53
# 44     165       50
# 45     165       51
# 48     169       55
# 49     158       54
# 51     166       63
# 52     161       53
# 57     162       48
# 58     159       50
# 59     164       55
# 60     162       45
# 61     167       49
# 62     159       51
# 66     160       53
# 72     166       58
# 73     159       49
# 76     159       47
# 79     161       50
